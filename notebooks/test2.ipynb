# %% [markdown]
# ```mermaid
# flowchart
#     subgraph SG1 [ ]
#         Produzent---P1(["`<ins>ProdId</ins>`"])
#         Produzent---P3(((Zertifikate)))
#     end
#     subgraph SG2 [ ]
#         Bauteil---B1(["`<ins>Name</ins>`"])
#         Bauteil---B2([Gewicht])
#         Bauteil---B3([Größe])
#         Bauteil---B7([Farbe])
#         B3([Größe])---B4([Länge])
#         B3([Größe])---B5([Breite])
#         B3([Größe])---B6([Höhe])
#     end
#     subgraph SG3 [ ]
#         Produzent--(1,*)---bauen{bauen}
#         bauen{bauen}--(1,1)---Bauteil
#         bauen{bauen}---H1([Jahr])
#         Bauteil--(2,3)---bestehen_aus{bestehen_aus}
#         bestehen_aus{bestehen_aus}--(0,*)---Bauteil
#     end
#     style SG1 fill:#ff0000,fill-opacity:0.0,stroke:#333,stroke-width:0px
#     style SG2 fill:#ff0000,fill-opacity:0.0,stroke:#333,stroke-width:0px
#     style SG3 fill:#ff0000,fill-opacity:0.0,stroke:#333,stroke-width:0px
#
#     fehlerFehlendeKnoten[Fehler: Es fehlen noch Enitäten, Attribute oder Relationships!]
#     style fehlerFehlendeKnoten fill:#fde2e1,stroke:#b91c1c,stroke-width:2p,font-weight:bold;
#     style B7 fill:#d9eaf7,stroke:#045a8d,stroke-width:2px
#     style bauen fill:#F4CCCC,stroke:#F4CCCC,color:#CC0000,stroke-width:2px,font-weight:bold;
#     fehlerFehlendeKanten[ Es fehlen noch Beziehungen zwischen Enitäten, Attributen oder Relationships!]
#     style fehlerFehlendeKanten fill:#fde2e1,stroke:#b91c1c,stroke-width:2p,font-weight:bold;
#     linkStyle 5 stroke:#FFD966,stroke-width:4px,color:#FFD966, fill:none;
#     linkStyle 12 stroke:#d62728,stroke-width:4px,color:#d62728,fill:none;
# ```

# %% [markdown]
# ```mermaid
# flowchart
#     subgraph SG1 [ ]
#         Produzent---P1(["`<ins>ProdId</ins>`"])
#         Produzent---P3(((Zertifikate)))
#     end
#     subgraph SG2 [ ]
#         Gerät---B1(["`<ins>Name</ins>`"])
#         Gerät---B2([Gewicht])
#         Gerät---B3([Größe])
#         Gerät---B7([Farbe])
#         B3([Größe])---B4([Länge])
#         B3([Größe])---B5([Breite])
#         B3([Größe])---B6([Höhe])
#     end
#     subgraph SG3 [ ]
#         Produzent--(1,*)---bauen{bauen}
#         bauen{bauen}--(1,1)---Gerät
#         bauen{bauen}---H1([Jahr])
#         Gerät--(2,3)---bestehen_aus{bestehen_aus}
#         bestehen_aus{bestehen_aus}--(0,*)---Gerät
#     end
#     style SG1 fill:#ff0000,fill-opacity:0.0,stroke:#333,stroke-width:0px
#     style SG2 fill:#ff0000,fill-opacity:0.0,stroke:#333,stroke-width:0px
#     style SG3 fill:#ff0000,fill-opacity:0.0,stroke:#333,stroke-width:0px
#
#     fehlerFehlendeKnoten[Fehler: Es fehlen noch Enitäten, Attribute oder Relationships!]
#     style fehlerFehlendeKnoten fill:#fde2e1,stroke:#b91c1c,stroke-width:2p,font-weight:bold;
#     style Gerät fill:#d9eaf7,stroke:#045a8d,stroke-width:2px
#     style B7 fill:#d9eaf7,stroke:#045a8d,stroke-width:2px
#     style bauen fill:#d9eaf7,stroke:#045a8d,stroke-width:2px
#     style Gerät fill:#F4CCCC,stroke:#F4CCCC,color:#CC0000,stroke-width:2px,font-weight:bold;
#     style bauen fill:#F4CCCC,stroke:#F4CCCC,color:#CC0000,stroke-width:2px,font-weight:bold;
#     fehlerFehlendeKanten[ Es fehlen noch Beziehungen zwischen Enitäten, Attributen oder Relationships!]
#     style fehlerFehlendeKanten fill:#fde2e1,stroke:#b91c1c,stroke-width:2p,font-weight:bold;
#     linkStyle 9 stroke:#FFD966,stroke-width:4px,color:#FFD966, fill:none;
#     linkStyle 11 stroke:#FFD966,stroke-width:4px,color:#FFD966, fill:none;
# ```
